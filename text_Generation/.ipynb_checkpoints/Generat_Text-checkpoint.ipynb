# %%
import os
os.environ["GEMINI_API_KEY"] = "AIzaSyDrOxWc8kngTTPCS26SZFa0fMNn9w16p7E"

# %%
from google import genai
from google.genai import types 
import os

client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents="How does AI work?",
    config=types.GenerateContentConfig(
        thinking_config=types.ThinkingConfig(thinking_level="low")
    ),
)

print(response.text)
# Out:
# To understand how Artificial Intelligence (AI) works, it helps to first understand how it differs from traditional software.
#
# In **traditional programming**, a human writes a set of explicit rules (e.g., "If the user clicks this button, change the screen to red").
#
# In **AI**, humans don't provide the rules. Instead, they provide a massive amount of **data** and an **algorithm**, and the AI figures out the patterns for itself.
#
# Here is the step-by-step breakdown of how modern AI works:
#
# ---
#
# ### 1. Data: The Fuel
# AI needs information to learn from. This data can be text, images, sensor readings, or numbers.
# *   If you want an AI to recognize a cat, you feed it thousands of pictures of cats.
# *   If you want an AI to write like a human, you feed it millions of books and articles.
#
# ### 2. Algorithms: The Engine
# An algorithm is a set of mathematical instructions. In modern AI, we mostly use **Machine Learning**, and specifically a sub-field called **Deep Learning**.
# *   Deep Learning uses **Neural Networks**, which are mathematical structures inspired by the human brain.
# *   These networks consist of layers of "neurons" (code) that pass information to one another.
#
# ### 3. The Training Process (Learning)
# This is where the "intelligence" is built. It happens through a cycle of trial and error:
# 1.  **The Guess:** The AI is shown a piece of data (e.g., a photo of a dog). Initially, it has no idea what it is, so it makes a random guess: "It’s a toaster."
# 2.  **The Error Check:** The system compares its guess to the correct label. It realizes it was 100% wrong.
# 3.  **Adjustment (Backpropagation):** The AI goes back through its internal connections and adjusts the "weights" (the importance of certain signals). It says, "Next time I see floppy ears and a wet nose, I should lean away from 'toaster' and closer to 'animal.'"
# 4.  **Iteration:** This happens millions or billions of times until the AI can identify patterns with high accuracy.
#
# ### 4. Pattern Recognition
# AI doesn't "understand" things the way humans do. It processes things as **numbers**.
# *   **Images:** AI sees an image as a grid of numbers representing colors and brightness. It learns that certain arrangements of numbers usually mean "edge," "circle," or "face."
# *   **Language:** AI turns words into lists of numbers called **Embeddings**. It learns that the word "King" is mathematically related to "Queen" in the same way "Man" is related to "Woman."
#
# ### 5. Prediction and Generation
# Once an AI is trained, it is used to make predictions:
# *   **Discriminative AI:** "Based on what I’ve learned, there is a 98% chance this email is spam."
# *   **Generative AI (like ChatGPT):** "Based on the first five words of this sentence, the most statistically likely next word is 'apple'." It predicts the next piece of data in a sequence to create something new.
#
# ### 6. The Human Element (Feedback)
# Most AI systems undergo **RLHF (Reinforcement Learning from Human Feedback)**. Humans rank the AI's answers, telling it which responses were helpful and which were nonsensical. This "fine-tunes" the AI to behave in a way that is useful to people.
#
# ---
#
# ### Summary Analogy
# Think of AI like a **skilled pianist**.
# *   The **Data** is the sheet music.
# *   The **Neural Network** is the piano.
# *   The **Training** is the thousands of hours of practice.
# *   The **Output** is the performance.
#
# The pianist doesn't necessarily "feel" the music the way you do, but through immense practice, they have learned exactly which keys to press in which order to produce a beautiful result.

# %%
from google import genai
from google.genai import types

client = genai.Client()

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents=["Explain how AI works"],
    config=types.GenerateContentConfig(
        temperature=0.1
    )
)
print(response.text)
# Out:
# To understand how Artificial Intelligence (AI) works, it helps to stop thinking of it as a "robot brain" and start thinking of it as **extremely advanced pattern recognition.**
#
# At its core, AI is a blend of math, data, and massive computing power. Here is the step-by-step breakdown of how it functions.
#
# ---
#
# ### 1. The Fuel: Data
# AI cannot "think" on its own; it needs to learn from examples. This is called **Data**.
# *   If you want an AI to recognize a cat, you feed it millions of pictures of cats.
# *   If you want it to speak English, you feed it the entire internet’s worth of text.
# *   **The Rule:** The more high-quality data an AI has, the better it becomes at its job.
#
# ### 2. The Engine: Algorithms and Machine Learning
# An **algorithm** is just a set of instructions. Traditional software uses "If-Then" logic (e.g., *If* the user clicks this button, *then* open this file).
#
# **Machine Learning (ML)** is different. Instead of a human writing every rule, we give the computer a goal and an algorithm that allows it to **figure out the rules itself** by finding patterns in the data.
#
# ### 3. The Structure: Neural Networks
# Modern AI (like ChatGPT or Midjourney) uses a structure called a **Neural Network**, inspired by the human brain.
# *   **Layers:** Imagine thousands of tiny filters arranged in layers.
# *   **Processing:** When you give an AI an image of a dog, the first layer might look for simple lines. The next layer looks for shapes (circles, triangles). The next looks for features (ears, wet nose).
# *   **The Result:** By the final layer, the AI calculates the probability: "There is a 98% chance this is a Golden Retriever."
#
# ### 4. The Process: Training and Feedback
# How does the AI know if it’s right? Through a process called **Training.**
# 1.  **Trial and Error:** The AI makes a guess.
# 2.  **The Correction:** If the AI identifies a dog as a "muffin," the programmers (or the system itself) tell it that it was wrong.
# 3.  **Weight Adjustment:** The AI goes back and adjusts its internal mathematical connections (called "weights") so it won't make that mistake again.
# 4.  **Iteration:** This happens millions of times until the AI is incredibly accurate.
#
# ### 5. Generative AI (The "Magic" of ChatGPT)
# You might wonder how AI "creates" things. Large Language Models (LLMs) like ChatGPT work on **Probability.**
#
# When you ask a question, the AI isn't "thinking." It is calculating: *"Based on all the text I’ve ever read, what is the most statistically likely next word in this sentence?"* It builds its answer one word at a time, like a super-powered version of the autocomplete on your phone.
#
# ---
#
# ### Summary: The Three Pillars
# To make AI work, you need three things:
# 1.  **Data:** The examples to learn from.
# 2.  **Compute:** Massive computers (GPUs) to crunch the numbers.
# 3.  **Algorithms:** The mathematical formulas that allow the system to learn from its mistakes.
#
# ### Is it "Intelligent"?
# Not in the way humans are. AI doesn't have feelings, consciousness, or a "soul." It is a **prediction machine.** It uses the past (data) to predict the most helpful output for the present.
