# %%
import os
os.environ["GEMINI_API_KEY"] = "AIzaSyDrOxWc8kngTTPCS26SZFa0fMNn9w16p7E"

# %%
from google import genai
import os

client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents="How does AI work?",
    config=types.GenerateContentConfig(
        thinking_config=types.ThinkingConfig(thinking_level="low")
    ),
)

print(response.text)
# Out:
# At its simplest level, Artificial Intelligence (AI) is a field of computer science that builds systems capable of performing tasks that typically require human intelligence. This includes things like recognizing faces, translating languages, making decisions, or writing text.
#
# Here is a breakdown of how it works, moving from the basic concept to the complex technology.
#
# ---
#
# ### 1. The Core Shift: From "Rules" to "Patterns"
# To understand AI, you have to understand how it differs from traditional computer programming.
#
# *   **Traditional Programming:** A human writes specific instructions. *"If the user clicks this button, show this picture."* The computer is a fast follower of recipes.
# *   **AI (Machine Learning):** Instead of giving the computer instructions, we give it **data** and the **goal**. The computer uses math to find the patterns in that data to reach the goal.
#
# **Analogy:** Traditional programming is like giving someone a map. AI is like giving someone 1,000 photos of the destination and letting them figure out the path themselves.
#
# ---
#
# ### 2. The Engine: Machine Learning (ML)
# Most AI today is actually **Machine Learning**. This is the process of "training" a computer to get better at a task through experience.
#
# 1.  **Data Input:** You feed the system massive amounts of data (e.g., millions of pictures of cats and dogs).
# 2.  **Training:** The system looks for features. It might notice that "cats" often have pointed ears and "dogs" have longer snouts.
# 3.  **The Model:** After looking at millions of examples, the system creates a "model"—a mathematical representation of what a cat looks like.
# 4.  **Inference:** When you show the model a new photo it has never seen before, it uses the patterns it learned to say, "There is a 98% chance this is a cat."
#
# ---
#
# ### 3. The Brain: Neural Networks and Deep Learning
# The most advanced AI (like ChatGPT or self-driving cars) uses **Neural Networks**. These are inspired by the human brain.
#
# *   **Layers:** A neural network is made of layers of "neurons" (mathematical functions).
# *   **Processing:** Data enters the "input layer," passes through several "hidden layers" (where it is processed), and comes out the "output layer."
# *   **Deep Learning:** When a neural network has many, many hidden layers, it is called "Deep Learning." This allows the AI to understand very complex concepts, like the nuances of human emotion in text.
#
# ---
#
# ### 4. How Generative AI (like ChatGPT) works
# Generative AI doesn't just "look" at data; it "creates" new data. It works on a concept called **Next-Token Prediction.**
#
# When you ask an AI a question, it isn't "thinking." Instead, it is calculating the statistical probability of which word (or part of a word, called a "token") should come next based on its training.
#
# *   If you type "The cat sat on the...", the AI’s math tells it that "mat" is 80% likely, "floor" is 15% likely, and "refrigerator" is 1% likely.
# *   It picks the most likely word and repeats the process for the next word. Because it has "read" almost everything on the internet, its predictions are incredibly accurate and seem human.
#
# ---
#
# ### 5. The Three Essential Ingredients
# For AI to work, you need three things:
#
# 1.  **Data:** AI is only as good as the information it learns from. (Text, images, sensor data, etc.)
# 2.  **Compute Power:** Training these models requires thousands of powerful computer chips (GPUs) running for weeks or months.
# 3.  **Algorithms:** The mathematical formulas that tell the computer how to learn from the data.
#
# ---
#
# ### Summary
# AI works by **calculating probabilities.** It doesn't "know" things the way humans do; it uses massive amounts of data and intense mathematical processing to identify patterns and predict what the result should be.
#
# Whether it's a Netflix recommendation or a medical diagnosis, the AI is simply saying: **"Based on everything I have seen before, this is the most likely answer."**
