# %%
import os
os.environ["GEMINI_API_KEY"] = "AIzaSyCvA93aG6PIrcYDhuKacB3X2C7U7izxjXw"

# %%
from google import genai
from google.genai import types 
import os

client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents="How does AI work?",
    config=types.GenerateContentConfig(
        thinking_config=types.ThinkingConfig(thinking_level="low")
    ),
)

print(response.text)
# Out:
# At its simplest level, AI doesn’t "think" the way a human does. Instead, it **recognizes patterns in massive amounts of data.**
#
# To understand how it works, it helps to compare it to traditional computer programming.
#
# ### 1. Traditional Programming vs. AI
# *   **Traditional Programming:** A human writes a list of specific instructions (If X happens, do Y). The computer follows these rules like a recipe.
# *   **AI (Machine Learning):** Instead of giving the computer rules, we give it **data** and the **answer** we want. The computer then calculates its own rules to bridge the gap.
#
# ### 2. The Core Ingredient: Data
# AI is fueled by data—text, images, numbers, or sounds.
# *   If you want an AI to recognize a cat, you don't describe what a cat looks like (whiskers, ears, etc.).
# *   Instead, you show it 10 million photos of cats and 10 million photos of things that *aren't* cats.
#
# ### 3. The "Brain": Neural Networks
# Most modern AI (like ChatGPT or Midjourney) uses something called a **Neural Network**. This is a mathematical structure inspired by the human brain.
#
# *   **Layers:** A neural network consists of layers of "neurons" (which are actually just small pieces of code that perform math).
# *   **Weights:** Each connection between these neurons has a "weight." This determines how much importance to give a certain piece of information.
# *   **Processing:** As data passes through these layers, the AI looks for increasingly complex patterns. For an image, the first layer might look for simple lines; the middle layer looks for shapes (circles, squares); the final layer recognizes a face.
#
# ### 4. The Process: How It Learns
# The magic happens during a phase called **Training**.
#
# 1.  **The Guess:** The AI is shown a picture of a dog. At first, its weights are random, so it might guess "it’s a toaster."
# 2.  **The Error:** The system compares its guess to the correct label ("No, it's a dog").
# 3.  **The Adjustment:** Using a mathematical process called **backpropagation**, the AI goes backward through its network and slightly tweaks its weights to be more accurate next time.
# 4.  **Repetition:** This happens millions of times until the AI’s "guess" is almost always correct.
#
# ### 5. Generative AI (The New Wave)
# You might be wondering how ChatGPT "writes" or DALL-E "paints." This is called **Generative AI**.
#
# These models (Large Language Models) work on **probability**. When you ask ChatGPT a question, it isn't "thinking." It is calculating the statistical probability of which word should come next based on all the text it has ever read.
#
# *   If you type "The cat sat on the...", the AI knows that "mat" or "floor" is statistically more likely than "refrigerator." It builds sentences one word at a time based on these complex patterns.
#
# ### Summary: The Three Pillars
# To make AI work, you need:
# 1.  **Algorithms:** The math formulas (Neural Networks).
# 2.  **Compute Power:** High-powered chips (GPUs) to run those formulas.
# 3.  **Data:** The information the AI learns from.
#
# **In short: AI works by using math to turn massive amounts of data into a "map" of patterns, which it then uses to make predictions or create new content.**

# %%
from google import genai
from google.genai import types

client = genai.Client()

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents=["Explain how AI works"],
    config=types.GenerateContentConfig(
        temperature=0.1
    )
)
print(response.text)
# Out:
# To understand how Artificial Intelligence (AI) works, it helps to stop thinking of it as a "robot brain" and start thinking of it as **extremely advanced pattern recognition.**
#
# At its core, AI is a blend of math, data, and code that allows computers to solve problems by identifying patterns rather than following a rigid set of instructions.
#
# Here is a step-by-step breakdown of how it works:
#
# ---
#
# ### 1. The Foundation: Data
# Traditional software follows "If-Then" logic (e.g., *If the user clicks this button, then open this file*). AI is different. It doesn't start with rules; it starts with **data**.
#
# To build an AI that can recognize a cat, you don't write code describing "pointy ears" or "whiskers." Instead, you feed the computer thousands of images labeled "cat" and thousands labeled "not cat."
#
# ### 2. The Engine: Machine Learning (ML)
# Machine Learning is the process that allows the computer to learn from that data.
# *   **The Algorithm:** This is the mathematical "recipe." It looks at the data and tries to find a mathematical relationship between the input (the image) and the output (the label "cat").
# *   **Trial and Error:** The AI starts by guessing. When it gets a guess wrong, a mathematical function (called an optimizer) adjusts the internal settings of the algorithm to make a better guess next time.
#
# ### 3. The Structure: Neural Networks
# The most powerful AI today uses **Deep Learning**, which is modeled loosely after the human brain. It uses "Neural Networks" consisting of layers of interconnected nodes:
# *   **Input Layer:** Receives the data (e.g., the pixels of a photo).
# *   **Hidden Layers:** These layers perform complex math. One layer might look for edges, the next for shapes, and the next for textures.
# *   **Output Layer:** The final result (e.g., "98% chance this is a cat").
#
# ### 4. The Process: Training vs. Inference
# AI goes through two distinct phases:
# 1.  **Training:** This is the "study" phase. The AI is run on massive supercomputers, processing billions of data points until its mathematical model is accurate.
# 2.  **Inference:** This is the "test" phase. Once the AI is trained, you can put it on a phone or a website. When you ask it a question or show it a photo, it uses its "learned" patterns to give you an answer instantly.
#
# ### 5. How Generative AI (like ChatGPT) works
# Generative AI is a specific type of AI that creates new content.
# *   **Prediction:** ChatGPT doesn't actually "know" facts. It is a "Large Language Model" (LLM) that has been trained on nearly all the public text on the internet.
# *   **Probability:** When you ask it a question, it calculates the **probability** of which word should come next based on the words that came before it. It’s essentially a super-powered version of the "autofill" on your smartphone.
#
# ---
#
# ### A Simple Analogy: The Baker
# Imagine you want to teach someone to bake the perfect loaf of bread, but you aren't allowed to give them a recipe.
#
# *   **Traditional Programming:** You give them a strict recipe: "Mix 500g flour, 300ml water, bake at 400 degrees."
# *   **AI (Machine Learning):** You put them in a kitchen with thousands of ingredients. They bake 10,000 loaves. Every time a loaf tastes bad, they change one tiny thing (more salt, less heat). Every time it tastes good, they remember what they did.
#
# Eventually, the baker "knows" how to make bread perfectly, not because they have a recipe, but because they have **learned the patterns** of what makes bread good.
#
# ### Summary
# AI works by:
# 1.  **Taking in massive amounts of data.**
# 2.  **Using math to find patterns** in that data.
# 3.  **Creating a model** based on those patterns.
# 4.  **Using that model to make predictions** or create new content when it sees new information.

# %%
from PIL import Image
from google import genai

client = genai.Client()

image = Image.open("organ.jpg")
response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents=[image, "Tell me about this instrument"]
)
print(response.text)
# Out:
# The instrument shown in the image is a **pipe organ**, specifically a smaller, self-contained version known as a **positive organ** or **chamber organ**.
#
# Unlike the massive pipe organs built into the architecture of cathedrals, a positive organ is designed to be movable (or "posited" in a location) and is often used for practice, chamber music, or in smaller chapels.
#
# Here are the main features of this instrument:
#
# ### 1. The Pipes
# The silver tubes arranged in a decorative pattern at the top are the sounding pipes. In a pipe organ, sound is produced by blowing pressurized air through these pipes.
# *   **Pitch:** The length of the pipe determines the note it plays; longer pipes produce lower sounds, while shorter pipes produce higher sounds.
# *   **Material:** These appear to be metal pipes (often made of a tin-lead alloy), which produce a bright, clear tone.
#
# ### 2. The Keyboard (Manual)
# The instrument features a single "manual" or keyboard. When a player presses a key, a valve opens inside the instrument, allowing air to flow from a pressurized windchest into the specific pipe corresponding to that note.
#
# ### 3. The Case
# The wooden structure is the "case." It doesn't just hold the instrument together; it also houses the internal mechanisms, including:
# *   **The Windchest:** A box that holds pressurized air.
# *   **The Blower:** In modern versions, an electric motor provides a steady stream of air. Historically, someone would have had to manually pump bellows at the back.
#
# ### 4. Common Uses
# *   **Continuo Playing:** In Baroque music, these small organs are frequently used to provide the harmonic foundation (basso continuo) for a small orchestra or choir.
# *   **Home/Studio Practice:** Because of their compact size, they are ideal for organists to practice at home without needing a full-sized church organ.
# *   **Small Churches:** They provide the majestic sound of a pipe organ in spaces that are too small for a full-scale installation.
#
# Unlike a **piano** (which uses hammers to strike strings) or a **reed organ/harmonium** (which uses vibrating metal reeds), this is a true **wind instrument**, making it essentially a giant collection of whistles controlled by a keyboard.

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content_stream(
    model="gemini-3-flash-preview",
    contents=["Explain how AI works"]
)
for chunk in response:
    print(chunk.text, end="")
# Out:
# To understand how Artificial Intelligence (AI) works, it helps to stop thinking of it as a "robot brain" and start thinking of it as **extremely advanced pattern recognition.**
#
# At its simplest level, AI works by combining large amounts of data with fast, iterative processing and intelligent algorithms, allowing the software to learn automatically from patterns in the data.
#
# Here is a breakdown of the process:
#
# ---
#
# ### 1. The Ingredients: Data and Algorithms
# AI needs two things to function:
# *   **Data (The Fuel):** This could be text, images, numbers, or recordings. If you want an AI to recognize a cat, you have to show it millions of pictures of cats.
# *   **Algorithms (The Engine):** These are sets of mathematical rules that tell the AI how to process that data.
#
# ### 2. The Method: Machine Learning
# Most modern AI uses a technique called **Machine Learning.** Instead of a human programmer writing a code for every single scenario (e.g., "If it has whiskers and pointy ears, it's a cat"), the programmer gives the AI a goal and the data to figure it out itself.
#
# There are three main ways it learns:
# *   **Supervised Learning:** We give the AI "labeled" data (e.g., "Here are 1,000 photos, these are cats, these are not").
# *   **Unsupervised Learning:** We give the AI raw data and ask it to find patterns or groups on its own (e.g., "Look at these 1,000 photos and tell me which ones look similar").
# *   **Reinforcement Learning:** This is like training a dog. The AI tries something; if it succeeds, it gets a "reward" (a numerical score); if it fails, it tries a different path.
#
# ### 3. The Structure: Neural Networks
# The most powerful AI today uses **Deep Learning**, which relies on "Neural Networks." These are layers of mathematical functions inspired by the human brain.
#
# *   **Input Layer:** Receives the data (like pixels in an image).
# *   **Hidden Layers:** These layers perform complex math to identify features. In an image, the first layer might find lines, the second might find circles, and the third might recognize a "face."
# *   **Output Layer:** The final guess (e.g., "98% chance this is a cat").
#
# ### 4. The Process: Training and Inference
# *   **Training:** This is the "school" phase. The AI is fed data and makes guesses. When it’s wrong, the algorithm adjusts its internal math (called **weights**) to be more accurate next time. This happens millions of times.
# *   **Inference:** Once the AI is trained, it is put into the real world. When you ask ChatGPT a question or use Face ID on your phone, the AI is "inferring" the answer based on the patterns it learned during training.
#
# ### 5. How Generative AI (like ChatGPT) Works
# Generative AI doesn't actually "know" facts. It is essentially a **super-powered autocomplete.**
# *   It has read almost everything on the public internet.
# *   It has learned the statistical probability of which words follow other words.
# *   When you ask it a question, it isn't "thinking"; it is calculating, word by word, what the most likely and helpful next word should be based on the patterns it has seen.
#
# ### An Analogy: The Mosaic
# Imagine you are standing very close to a massive mosaic made of billions of tiny colored tiles. Up close, you see nothing but individual dots.
# *   **AI** is like a system that can step back miles away until the dots form a clear picture.
# *   **Training** is the process of the AI moving back and forth until it finds the perfect distance to recognize the image.
# *   **The Result** is the AI’s ability to tell you exactly what that picture represents, even if it’s an image it has never seen before.
#
# ### Summary: Is it "Smart"?
# AI is not "intelligent" in the way humans are. It doesn't have consciousness, feelings, or a "soul." It is a **prediction machine.** It uses math to turn input (your prompt or photo) into output (an answer or a generated image) based on the patterns it discovered during its training.
