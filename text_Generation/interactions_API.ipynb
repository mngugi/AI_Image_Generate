# %% [markdown]
# <h1>Interactions API</h1>
#
# - The Interactions API (Beta) is a unified interface for interacting with Gemini models and agents. As an improved alternative to the generateContent API, it simplifies state management, tool orchestration, and long-running tasks.
#
# - The following example shows how to call the Interactions API with a text prompt.

# %%
import os
os.environ["GEMINI_API_KEY"] = "AIzaSyAZZsMnMQ-lE8mNVj9PSQFcllmN05mHCbY"

# %%
from google import genai

client = genai.Client()

interaction =  client.interactions.create(
    model="gemini-3-flash-preview",
    input="Tell me a short joke about programming."
)

print(interaction.outputs[-1].text)

# %% [markdown]
# ### Conversation
#
# You can build multi-turn conversations in two ways:
#
# - Statefully by referencing a previous interaction
# - Statelessly by providing the entire conversation history
# - Stateful conversation
#
# Pass the id from the previous interaction to the previous_interaction_id parameter to continue a conversation.

# %%
from google import genai

client = genai.Client()

interaction_1 =  client.interactions.create(
    model="gemini-3-flash-preview",
    input="hi my name is pete ."
)

interaction_2 = client.interactions.create(
    model="gemini-3-flash-preview",
    input="What is my name?",
    previous_interaction_id=interaction_1.id
    
)

print(f' Model: {interaction_2.outputs[-1].text}')

# %% [markdown]
# <h3>Stateless conversation</h3>
#
# - You can manage conversation history manually on the client side.

# %%
from google import genai

client = genai.Client()

conversation_history = [
    {
        "role": "user",
        "content": "What are the three largest cities in Spain?"
    }
]

interaction1 = client.interactions.create(
    model="gemini-3-flash-preview",
    input=conversation_history
)

print(f"Model: {interaction1.outputs[-1].text}")

conversation_history.append({"role": "model", "content": interaction1.outputs})
conversation_history.append({
    "role": "user",
    "content": "What is the most famous landmark in the second one?"
})

interaction2 = client.interactions.create(
    model="gemini-3-flash-preview",
    input=conversation_history
)

print(f"Model: {interaction2.outputs[-1].text}")

# %%
from google import genai
from google.genai import types

client = genai.Client()

# Upload image
uploaded = client.files.upload(file="organ.jpg")

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents=[
        "Describe the image.",
        types.Part.from_uri(
            file_uri=uploaded.uri,
            mime_type="image/jpeg"
        )
    ]
)

print(response.text)
