# %%
import os
os.environ["GEMINI_API_KEY"] = "AIzaSyCvA93aG6PIrcYDhuKacB3X2C7U7izxjXw"

# %% [markdown]
# ### Gemini thinking
#
# - The Gemini 3 and 2.5 series models use an internal "thinking process" that significantly improves their reasoning and multi-step planning abilities, making them highly effective for complex tasks such as coding, advanced mathematics, and data analysis.
#
# - This guide shows you how to work with Gemini's thinking capabilities using the Gemini API.
#
# ### Generating content with thinking
# - Initiating a request with a thinking model is similar to any other content generation request. The key difference lies in specifying one of the models with thinking support in the model field, as demonstrated in the following text generation example:

# %%
from google import genai

client = genai.Client()
prompt = "Explain the concept of Occam's Razor and provide a simple, everyday example."
response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents=prompt
)

print(response.text)
# Out:
# **Occam’s Razor** (also known as the Law of Parsimony) is a problem-solving principle that suggests that **the simplest explanation is usually the right one.**
#
# When you are faced with two or more competing theories that explain the same event, the one that requires the fewest assumptions is the one you should choose first.
#
# ### Why is it called a "Razor"?
# The term "razor" refers to the idea of "shaving away" unnecessary assumptions or complicated details that aren't supported by evidence, leaving you with the most likely truth.
#
# ### The Core Logic
# The more assumptions you have to make, the more "moving parts" there are in an explanation. If any one of those parts is wrong, the whole theory falls apart. A simple explanation has fewer ways to be wrong.
#
# ---
#
# ### A Simple, Everyday Example
#
# Imagine you wake up in the morning, walk into your kitchen, and find a **broken glass bowl** on the floor.
#
# **Explanation A (The Simple One):**
# The bowl was balanced precariously on the edge of the counter, and the vibration from the refrigerator or a slight breeze caused it to fall.
# *   *Assumptions:* Gravity works; the bowl was misplaced.
#
# **Explanation B (The Complex One):**
# A highly skilled burglar broke into your house without tripping the alarm, moved nothing except that bowl, dropped it by accident, felt guilty, and then climbed back out the window without taking anything.
# *   *Assumptions:* A burglar exists; they are skilled enough to bypass alarms; they have a very strange motive; they left no other evidence.
#
# **Applying Occam’s Razor:**
# While Explanation B is *technically* possible, it requires you to believe a long string of unlikely events. Explanation A explains the broken bowl perfectly without needing any extra "if/then" scenarios. Therefore, according to Occam’s Razor, you should assume **Explanation A** is the truth until proven otherwise.
#
# ---
#
# ### A Quick Note
# Occam’s Razor is a **rule of thumb**, not a law of physics. It doesn't mean the simplest answer is *always* right—sometimes the truth is complicated! However, it is a tool used by scientists, doctors, and detectives to avoid chasing "conspiracy theories" when a basic explanation fits the facts.

# %% [markdown]
# ### Thought summaries
# - Thought summaries are summarized versions of the model's raw thoughts and offer insights into the model's internal reasoning process. Note that thinking levels and budgets apply to the model's raw thoughts and not to thought summaries.
#
# - You can enable thought summaries by setting `includeThoughts` to `true` in your request configuration. You can then access the summary by iterating through the `response` parameter's parts, and checking the `thought` boolean.
#
# - Here's an example demonstrating how to enable and retrieve thought summaries without streaming, which returns a single, final thought summary with the response:

# %%
from google import genai
from google.genai import types

client = genai.Client()
prompt = "What is the sum of the first 50 prime numbers?"
response = client.models.generate_content(
  model="gemini-3-flash-preview",
  contents=prompt,
  config=types.GenerateContentConfig(
    thinking_config=types.ThinkingConfig(
      include_thoughts=True
    )
  )
)

for part in response.candidates[0].content.parts:
  if not part.text:
    continue
  if part.thought:
    print("Thought summary:")
    print(part.text)
    print()
  else:
    print("Answer:")
    print(part.text)
    print()
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[3], line 6
#       4 client = genai.Client()
#       5 prompt = "What is the sum of the first 50 prime numbers?"
# ----> 6 response = client.models.generate_content(
#       7   model="gemini-3-flash-preview",
#       8   contents=prompt,
#       9   config=types.GenerateContentConfig(
#      10     thinking_config=types.ThinkingConfig(
#      11       include_thoughts=True
#      12     )
#      13   )
#      14 )
#      16 for part in response.candidates[0].content.parts:
#      17   if not part.text:
#
# File ~/anaconda3/lib/python3.13/site-packages/google/genai/models.py:5227, in Models.generate_content(self, model, contents, config)
#    5225 while remaining_remote_calls_afc > 0:
#    5226   i += 1
# -> 5227   response = self._generate_content(
#    5228       model=model, contents=contents, config=parsed_config
#    5229   )
#    5231   function_map = _extra_utils.get_function_map(parsed_config)
#    5232   if not function_map:
#
# File ~/anaconda3/lib/python3.13/site-packages/google/genai/models.py:4009, in Models._generate_content(self, model, contents, config)
#    4006 request_dict = _common.convert_to_dict(request_dict)
#    4007 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4009 response = self._api_client.request(
#    4010     'post', path, request_dict, http_options
#    4011 )
#    4013 if config is not None and getattr(
#    4014     config, 'should_return_http_response', None
#    4015 ):
#    4016   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File ~/anaconda3/lib/python3.13/site-packages/google/genai/_api_client.py:1386, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1376 def request(
#    1377     self,
#    1378     http_method: str,
#    (...)   1381     http_options: Optional[HttpOptionsOrDict] = None,
#    1382 ) -> SdkHttpResponse:
#    1383   http_request = self._build_request(
#    1384       http_method, path, request_dict, http_options
#    1385   )
# -> 1386   response = self._request(http_request, http_options, stream=False)
#    1387   response_body = (
#    1388       response.response_stream[0] if response.response_stream else ''
#    1389   )
#    1390   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~/anaconda3/lib/python3.13/site-packages/google/genai/_api_client.py:1222, in BaseApiClient._request(self, http_request, http_options, stream)
#    1219     retry = tenacity.Retrying(**retry_kwargs)
#    1220     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1222 return self._retry(self._request_once, http_request, stream)
#
# File ~/anaconda3/lib/python3.13/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File ~/anaconda3/lib/python3.13/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~/anaconda3/lib/python3.13/site-packages/tenacity/__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     418 retry_exc = self.retry_error_cls(fut)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File ~/anaconda3/lib/python3.13/site-packages/tenacity/__init__.py:187, in RetryError.reraise(self)
#     185 def reraise(self) -> t.NoReturn:
#     186     if self.last_attempt.failed:
# --> 187         raise self.last_attempt.result()
#     188     raise self
#
# File ~/anaconda3/lib/python3.13/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/anaconda3/lib/python3.13/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/anaconda3/lib/python3.13/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/anaconda3/lib/python3.13/site-packages/google/genai/_api_client.py:1199, in BaseApiClient._request_once(self, http_request, stream)
#    1191 else:
#    1192   response = self._httpx_client.request(
#    1193       method=http_request.method,
#    1194       url=http_request.url,
#    (...)   1197       timeout=http_request.timeout,
#    1198   )
# -> 1199   errors.APIError.raise_for_response(response)
#    1200   return HttpResponse(
#    1201       response.headers, response if stream else [response.text]
#    1202   )
#
# File ~/anaconda3/lib/python3.13/site-packages/google/genai/errors.py:121, in APIError.raise_for_response(cls, response)
#     118 else:
#     119   response_json = response.body_segments[0].get('error', {})
# --> 121 cls.raise_error(response.status_code, response_json, response)
#
# File ~/anaconda3/lib/python3.13/site-packages/google/genai/errors.py:146, in APIError.raise_error(cls, status_code, response_json, response)
#     132 """Raises an appropriate APIError subclass based on the status code.
#     133
#     134 Args:
#    (...)    143   APIError: For other error status codes.
#     144 """
#     145 if 400 <= status_code < 500:
# --> 146   raise ClientError(status_code, response_json, response)
#     147 elif 500 <= status_code < 600:
#     148   raise ServerError(status_code, response_json, response)
#
# ClientError: 403 PERMISSION_DENIED. {'error': {'code': 403, 'message': 'Your API key was reported as leaked. Please use another API key.', 'status': 'PERMISSION_DENIED'}}

# %% [markdown]
# - And here is an example using thinking with streaming, which returns rolling, incremental summaries during generation:
